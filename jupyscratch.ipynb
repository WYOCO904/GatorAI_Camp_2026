# %%
# this is a comment 
def addition(a, b):
    return a + b
result = addition(2, 3)
print("The sum is:", result)
# Out:
# The sum is: 5

# %% [markdown]
# # hello

# %%
def addition(number_1, number_2):
    return number_1 + number_2
value_added=addition(2,3)
print("The sum is",value_added,"!")
print(f"I added two numbers together and the sum is {value_added}")
# Out:
# The sum is 5 !
# I added two numbers together and the sum is 5
